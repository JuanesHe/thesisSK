# %%
import scipy.io
import numpy as np
import urx
rob = urx.Robot("192.168.88.249")

# %%
def Jacobian(q1,q2,q3,q4,q5,q6):
    import numpy as np
    JA11 = (float) (2247*np.cos(q1))/20000 + (819*np.cos(q1)*np.cos(q5))/10000 + (4873*np.cos(q2)*np.sin(q1))/20000 - (1707*np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)) + np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2))))/10000 - (853*np.sin(q1)*np.sin(q2)*np.sin(q3))/4000 + (853*np.cos(q2)*np.cos(q3)*np.sin(q1))/4000
    JA12 = float (4873*np.cos(q1)*np.sin(q2))/20000 + (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3))))/10000 + (853*np.cos(q1)*np.cos(q2)*np.sin(q3))/4000 + (853*np.cos(q1)*np.cos(q3)*np.sin(q2))/4000
    JA13 = float (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3))))/10000 + (853*np.cos(q1)*np.cos(q2)*np.sin(q3))/4000 + (853*np.cos(q1)*np.cos(q3)*np.sin(q2))/4000
    JA14 = float (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3))))/10000
    JA15 = float (- (819*np.sin(q1)*np.sin(q5))/10000 - (819*np.cos(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2))))/10000)
    JA16 = 0
    JA21 = float (2247*np.sin(q1))/20000 - (4873*np.cos(q1)*np.cos(q2))/20000 + (819*np.cos(q5)*np.sin(q1))/10000 + (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2))))/10000 - (853*np.cos(q1)*np.cos(q2)*np.cos(q3))/4000 + (853*np.cos(q1)*np.sin(q2)*np.sin(q3))/4000
    JA22 = float (4873*np.sin(q1)*np.sin(q2))/20000 - (1707*np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000 - (1707*np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)) - np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1))))/10000 + (853*np.cos(q2)*np.sin(q1)*np.sin(q3))/4000 + (853*np.cos(q3)*np.sin(q1)*np.sin(q2))/4000
    JA23 = float (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)) - np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1))))/10000 - (1707*np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 - (1707*np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000 + (853*np.cos(q2)*np.sin(q1)*np.sin(q3))/4000 + (853*np.cos(q3)*np.sin(q1)*np.sin(q2))/4000
    JA24 = float (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)) - np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1))))/10000 - (1707*np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 - (1707*np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000
    JA25 = float (819*np.cos(q1)*np.sin(q5))/10000 + (819*np.cos(q5)*(np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)) + np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2))))/10000
    JA26 = 0
    JA31 = 0
    JA32 = float (853*np.sin(q2)*np.sin(q3))/4000 - (853*np.cos(q2)*np.cos(q3))/4000 - (4873*np.cos(q2))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2))))/10000 + (1707*np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)))/20000
    JA33 = float (853*np.sin(q2)*np.sin(q3))/4000 - (853*np.cos(q2)*np.cos(q3))/4000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2))))/10000 + (1707*np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)))/20000
    JA34 = float (1707*np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2))))/10000 + (1707*np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)))/20000
    JA35 = float (-(819*np.cos(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3))))/10000)
    JA36 = 0
    JA41 = 0 
    JA42 = np.sin(q1)
    JA43 = np.sin(q1)
    JA44 = np.sin(q1)
    JA45 = np.cos(q1)*np.cos(q2)*np.cos(q3)*np.sin(q4) + np.cos(q1)*np.cos(q2)*np.cos(q4)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.cos(q4)*np.sin(q2) - np.cos(q1)*np.sin(q2)*np.sin(q3)*np.sin(q4)  
    JA46 = np.cos(q5)*np.sin(q1) - np.cos(q1)*np.cos(q2)*np.cos(q3)*np.cos(q4)*np.sin(q5) + np.cos(q1)*np.cos(q2)*np.sin(q3)*np.sin(q4)*np.sin(q5) + np.cos(q1)*np.cos(q3)*np.sin(q2)*np.sin(q4)*np.sin(q5) + np.cos(q1)*np.cos(q4)*np.sin(q2)*np.sin(q3)*np.sin(q5)
    JA51 = 0
    JA52 = -np.cos(q1)
    JA53 = -np.cos(q1)
    JA54 = -np.cos(q1)
    JA55 = np.cos(q2)*np.cos(q3)*np.sin(q1)*np.sin(q4) + np.cos(q2)*np.cos(q4)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.cos(q4)*np.sin(q1)*np.sin(q2) - np.sin(q1)*np.sin(q2)*np.sin(q3)*np.sin(q4)
    JA56 = np.cos(q2)*np.sin(q1)*np.sin(q3)*np.sin(q4)*np.sin(q5) - np.cos(q2)*np.cos(q3)*np.cos(q4)*np.sin(q1)*np.sin(q5) - np.cos(q1)*np.cos(q5) + np.cos(q3)*np.sin(q1)*np.sin(q2)*np.sin(q4)*np.sin(q5) + np.cos(q4)*np.sin(q1)*np.sin(q2)*np.sin(q3)*np.sin(q5)
    JA61 = 1
    JA62 = 0 
    JA63 = 0 
    JA64 = 0 
    JA65 = -np.cos(q2 + q3 + q4) 
    JA66 = np.cos(q2 + q3 + q4 + q5)/2 - np.cos(q2 + q3 + q4 - q5)/2
    JA = np.matrix([[JA11,JA12,JA13,JA14,JA15,JA16],[JA21,JA22,JA23,JA24,JA25,JA26],[JA31,JA32,JA33,JA34,JA35,JA36],[JA41,JA42,JA43,JA44,JA45,JA46],[JA51,JA52,JA53,JA54,JA55,JA56],[JA61,JA62,JA63,JA64,JA65,JA66]])
    return (JA)

# %%
def pos_rob(q1,q2,q3,q4,q5,q6):
    x = (2247*sin(q1))/20000 - (4873*cos(q1)*cos(q2))/20000 + (819*cos(q5)*sin(q1))/10000 + (1707*cos(q4)*(cos(q1)*cos(q2)*sin(q3) + cos(q1)*cos(q3)*sin(q2)))/20000 + (1707*sin(q4)*(cos(q1)*cos(q2)*cos(q3) - cos(q1)*sin(q2)*sin(q3)))/20000 - (819*sin(q5)*(cos(q4)*(cos(q1)*cos(q2)*cos(q3) - cos(q1)*sin(q2)*sin(q3)) - sin(q4)*(cos(q1)*cos(q2)*sin(q3) + cos(q1)*cos(q3)*sin(q2))))/10000 - (853*cos(q1)*cos(q2)*cos(q3))/4000 + (853*cos(q1)*sin(q2)*sin(q3))
    y = (1707*cos(q4)*(cos(q2)*sin(q1)*sin(q3) + cos(q3)*sin(q1)*sin(q2)))/20000 - (819*cos(q1)*cos(q5))/10000 - (4873*cos(q2)*sin(q1))/20000 - (2247*cos(q1))/20000 - (1707*sin(q4)*(sin(q1)*sin(q2)*sin(q3) - cos(q2)*cos(q3)*sin(q1)))/20000 + (819*sin(q5)*(cos(q4)*(sin(q1)*sin(q2)*sin(q3) - cos(q2)*cos(q3)*sin(q1)) + sin(q4)*(cos(q2)*sin(q1)*sin(q3) + cos(q3)*sin(q1)*sin(q2))))/10000 + (853*sin(q1)*sin(q2)*sin(q3))/4000 - (853*cos(q2)*cos(q3)*sin(q1))/4000
    z = (1707*sin(q4)*(cos(q2)*sin(q3) + cos(q3)*sin(q2)))/20000 - (853*cos(q2)*sin(q3))/4000 - (853*cos(q3)*sin(q2))/4000 - (819*sin(q5)*(cos(q4)*(cos(q2)*sin(q3) + cos(q3)*sin(q2)) + sin(q4)*(cos(q2)*cos(q3) - sin(q2)*sin(q3))))/10000 - (1707*cos(q4)*(cos(q2)*cos(q3) - sin(q2)*sin(q3)))/20000 - (4873*sin(q2))/20000 + 1519/10000
    h = [float(x),float(y),float(z)]
    return h

# %%
Jacobian(0,0,0,0,0,0)

# %%
import time
import sys
import urx
import numpy as np
import keyboard
import json
import numpy as np
from numpy.linalg import inv

def Jacobian(q1,q2,q3,q4,q5,q6):
    import numpy as np
    JA11 = (float) (2247*np.cos(q1))/20000 + (819*np.cos(q1)*np.cos(q5))/10000 + (4873*np.cos(q2)*np.sin(q1))/20000 - (1707*np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)) + np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2))))/10000 - (853*np.sin(q1)*np.sin(q2)*np.sin(q3))/4000 + (853*np.cos(q2)*np.cos(q3)*np.sin(q1))/4000
    JA12 = float (4873*np.cos(q1)*np.sin(q2))/20000 + (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3))))/10000 + (853*np.cos(q1)*np.cos(q2)*np.sin(q3))/4000 + (853*np.cos(q1)*np.cos(q3)*np.sin(q2))/4000
    JA13 = float (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3))))/10000 + (853*np.cos(q1)*np.cos(q2)*np.sin(q3))/4000 + (853*np.cos(q1)*np.cos(q3)*np.sin(q2))/4000
    JA14 = float (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3))))/10000
    JA15 = float (- (819*np.sin(q1)*np.sin(q5))/10000 - (819*np.cos(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2))))/10000)
    JA16 = 0
    JA21 = float (2247*np.sin(q1))/20000 - (4873*np.cos(q1)*np.cos(q2))/20000 + (819*np.cos(q5)*np.sin(q1))/10000 + (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2))))/10000 - (853*np.cos(q1)*np.cos(q2)*np.cos(q3))/4000 + (853*np.cos(q1)*np.sin(q2)*np.sin(q3))/4000
    JA22 = float (4873*np.sin(q1)*np.sin(q2))/20000 - (1707*np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000 - (1707*np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)) - np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1))))/10000 + (853*np.cos(q2)*np.sin(q1)*np.sin(q3))/4000 + (853*np.cos(q3)*np.sin(q1)*np.sin(q2))/4000
    JA23 = float (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)) - np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1))))/10000 - (1707*np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 - (1707*np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000 + (853*np.cos(q2)*np.sin(q1)*np.sin(q3))/4000 + (853*np.cos(q3)*np.sin(q1)*np.sin(q2))/4000
    JA24 = float (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)) - np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1))))/10000 - (1707*np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 - (1707*np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000
    JA25 = float (819*np.cos(q1)*np.sin(q5))/10000 + (819*np.cos(q5)*(np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)) + np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2))))/10000
    JA26 = 0
    JA31 = 0
    JA32 = float (853*np.sin(q2)*np.sin(q3))/4000 - (853*np.cos(q2)*np.cos(q3))/4000 - (4873*np.cos(q2))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2))))/10000 + (1707*np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)))/20000
    JA33 = float (853*np.sin(q2)*np.sin(q3))/4000 - (853*np.cos(q2)*np.cos(q3))/4000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2))))/10000 + (1707*np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)))/20000
    JA34 = float (1707*np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2))))/10000 + (1707*np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)))/20000
    JA35 = float (-(819*np.cos(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3))))/10000)
    JA36 = 0
    JA41 = 0 
    JA42 = np.sin(q1)
    JA43 = np.sin(q1)
    JA44 = np.sin(q1)
    JA45 = np.cos(q1)*np.cos(q2)*np.cos(q3)*np.sin(q4) + np.cos(q1)*np.cos(q2)*np.cos(q4)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.cos(q4)*np.sin(q2) - np.cos(q1)*np.sin(q2)*np.sin(q3)*np.sin(q4)  
    JA46 = np.cos(q5)*np.sin(q1) - np.cos(q1)*np.cos(q2)*np.cos(q3)*np.cos(q4)*np.sin(q5) + np.cos(q1)*np.cos(q2)*np.sin(q3)*np.sin(q4)*np.sin(q5) + np.cos(q1)*np.cos(q3)*np.sin(q2)*np.sin(q4)*np.sin(q5) + np.cos(q1)*np.cos(q4)*np.sin(q2)*np.sin(q3)*np.sin(q5)
    JA51 = 0
    JA52 = -np.cos(q1)
    JA53 = -np.cos(q1)
    JA54 = -np.cos(q1)
    JA55 = np.cos(q2)*np.cos(q3)*np.sin(q1)*np.sin(q4) + np.cos(q2)*np.cos(q4)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.cos(q4)*np.sin(q1)*np.sin(q2) - np.sin(q1)*np.sin(q2)*np.sin(q3)*np.sin(q4)
    JA56 = np.cos(q2)*np.sin(q1)*np.sin(q3)*np.sin(q4)*np.sin(q5) - np.cos(q2)*np.cos(q3)*np.cos(q4)*np.sin(q1)*np.sin(q5) - np.cos(q1)*np.cos(q5) + np.cos(q3)*np.sin(q1)*np.sin(q2)*np.sin(q4)*np.sin(q5) + np.cos(q4)*np.sin(q1)*np.sin(q2)*np.sin(q3)*np.sin(q5)
    JA61 = 1
    JA62 = 0 
    JA63 = 0 
    JA64 = 0 
    JA65 = -np.cos(q2 + q3 + q4) 
    JA66 = np.cos(q2 + q3 + q4 + q5)/2 - np.cos(q2 + q3 + q4 - q5)/2
    JA = np.matrix([[JA11,JA12,JA13,JA14,JA15,JA16],[JA21,JA22,JA23,JA24,JA25,JA26],[JA31,JA32,JA33,JA34,JA35,JA36],[JA41,JA42,JA43,JA44,JA45,JA46],[JA51,JA52,JA53,JA54,JA55,JA56],[JA61,JA62,JA63,JA64,JA65,JA66]])
    return (JA)

def pos_rob(q1,q2,q3,q4,q5,q6):
    x = (2247*np.sin(q1))/20000 - (4873*np.cos(q1)*np.cos(q2))/20000 + (819*np.cos(q5)*np.sin(q1))/10000 + (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2))))/10000 - (853*np.cos(q1)*np.cos(q2)*np.cos(q3))/4000 + (853*np.cos(q1)*np.sin(q2)*np.sin(q3))/4000
    y = (1707*np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 - (819*np.cos(q1)*np.cos(q5))/10000 - (4873*np.cos(q2)*np.sin(q1))/20000 - (2247*np.cos(q1))/20000 - (1707*np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)) + np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2))))/10000 + (853*np.sin(q1)*np.sin(q2)*np.sin(q3))/4000 - (853*np.cos(q2)*np.cos(q3)*np.sin(q1))/4000
    z = (1707*np.sin(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)))/20000 - (853*np.cos(q2)*np.sin(q3))/4000 - (853*np.cos(q3)*np.sin(q2))/4000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3))))/10000 - (1707*np.cos(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)))/20000 - (4873*np.sin(q2))/20000 + 1519/10000
    h = [float(x),float(y),float(z)]
    return h

interval = True

try :
    with open('data.json', 'r') as fa:
        data = json.load(fa)
        T = data['person']['T']
        k = data['person']['k']
        m = data['person']['m']
        d = data['person']['d']
except:
    print('file error')
    interval = False  

try:
    rob = urx.Robot("192.168.88.249")
except:
    print('robot error')
    interval = False


if interval:


    #Controller
    dt = 0.1

    r = 5
    phi = np.linspace(0,2*np.pi,9)
    teta = np.linspace(0,np.pi,5)

    sint =  np.sin(teta)
    sint=np.asmatrix(sint)
    sint= sint.transpose(1,0)
    cosp = np.cos(phi)
    cosp=np.asmatrix(cosp)
    x = r * sint*cosp;
    x = np.array(x.reshape(45,1))

    sint =  np.sin(teta)
    sint=np.asmatrix(sint)
    sint= sint.transpose(1,0)
    sinp = np.sin(phi)
    sinp=np.asmatrix(sinp)
    y = r * sint*sinp;
    y = np.array(y.reshape(45,1))

    cost =  np.cos(teta)
    cost = np.asmatrix(cost)
    cost = cost.transpose(1,0)
    cosp = np.cos(phi*0)
    cosp = np.asmatrix(cosp)
    z = r * cost*cosp;
    z = np.array(z.reshape(45,1))


    print('1')
    P = np.array([0,0,0]).reshape(3,1);
    rno = np.concatenate((x, y, z ), axis=0).reshape(3,45)
    V = np.array([0,0,0]).reshape(3,1)
    Po = np.array([2,2,10]).reshape(3,1);
    ro = np.array([2,2,0]).reshape(3,1);
    rn = rno + Po
    Pa = np.zeros((3,1));
    lamda = 0.01

    while True:
        
        if keyboard.is_pressed('q'):  # if key 'q' is pressed 
            print('You Pressed A Key!')
            break  # finishing the loop

        try :
            with open('data.json', 'r') as fa:
                data = json.load(fa)
                T = data['person']['T']
                k = data['person']['k']
                m = data['person']['m']
                d = data['person']['d']
                vmax = data['person']['vmax']
                x_refr = data['person']['xref']
                y_refr = data['person']['yref']
                z_refr = data['person']['zref']
        except:
            print('file error')


        t = rob.get_pose()
        print("Transformation from base to tcp is: ", t)


        pose = rob.getl()
        xn = float(pose[0])
        yn = float(pose[1])
        zn = float(pose[2])
        P = np.zeros((3,1));
        P[0,0] = float(xn)
        P[1,0] = float(yn)
        P[2,0] = float(zn)
        print('Punto actual',P)
        
        Po = np.zeros((3,1));   
        Po[0,0] = float(x_refr)
        Po[1,0] = float(y_refr)
        Po[2,0] = float(z_refr)
        print('punto deseado',Po)
        
        rn = rno + Po
        rf = P - rn 
        dr = P - Po      
        mrf = np.sqrt(np.power(rf[0,:],2) + np.power(rf[1,:],2) + np.power(rf[2,:],2) );
        urf = rf/mrf
        Fk = (-k)*urf*(np.dot(dr.reshape(1,3),urf))
        Fd = (-d)*urf*(np.dot(V.reshape(1,3),urf))
        a = np.sum(Fk+Fd, axis=1) /m
        a.resize(3,1)
        V = a*T + V    
        #print ('velocidad',V)          

        
        vx1 = V[0,0]
        vy1 = V[1,0]
        vz1 = V[2,0]
        
        if (vx1 > vmax):
            vx1 = vmax;
        elif (vx1 < -vmax):
            vx1 = -vmax;

        if (vy1 > vmax):
            vy1 = vmax;
        elif (vy1 < -vmax):
            vy1 = -vmax;

        if (vz1 > vmax):
            vz1 = vmax;
        elif (vz1 < -vmax):
            vz1 = -vmax;


        V[0,0] = vx1
        V[1,0] = vy1
        V[2,0] = vz1

        print ('velocidad',vx1,vy1,vz1) 

        J = rob.getj()
        print(J)
        JA = Jacobian(J[0],J[1],J[2],J[3],J[4],J[5])
        JAp = JA.transpose();
        JA1 = JA * JAp + np.eye(6)*lamda
        J2 = inv(JA1)*JA
        C = J2.transpose()*np.matrix(([[V[0,0]],[V[1,0]],[V[2,0]],[0],[0],[0]]))
        J = [float(C[0,0]), float(C[1,0]), float(C[2,0]), float(C[3,0]), float(C[4,0]), float(C[5,0])]
        try:
            rob.speedj(J,acc=0.02, min_time=3)
        except:
            print('sent')

        time.sleep(0.01)



else:
    print('finishing')
    try:
        rob.stopl()
    except:
        print('No')

# %%
import time
import sys
import urx
import numpy as np
import keyboard
import json
import numpy as np
from numpy.linalg import inv

def Jacobian(q1,q2,q3,q4,q5,q6):
    import numpy as np
    JA11 = (float) (2247*np.cos(q1))/20000 + (819*np.cos(q1)*np.cos(q5))/10000 + (4873*np.cos(q2)*np.sin(q1))/20000 - (1707*np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)) + np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2))))/10000 - (853*np.sin(q1)*np.sin(q2)*np.sin(q3))/4000 + (853*np.cos(q2)*np.cos(q3)*np.sin(q1))/4000
    JA12 = float (4873*np.cos(q1)*np.sin(q2))/20000 + (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3))))/10000 + (853*np.cos(q1)*np.cos(q2)*np.sin(q3))/4000 + (853*np.cos(q1)*np.cos(q3)*np.sin(q2))/4000
    JA13 = float (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3))))/10000 + (853*np.cos(q1)*np.cos(q2)*np.sin(q3))/4000 + (853*np.cos(q1)*np.cos(q3)*np.sin(q2))/4000
    JA14 = float (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3))))/10000
    JA15 = float (- (819*np.sin(q1)*np.sin(q5))/10000 - (819*np.cos(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2))))/10000)
    JA16 = 0
    JA21 = float (2247*np.sin(q1))/20000 - (4873*np.cos(q1)*np.cos(q2))/20000 + (819*np.cos(q5)*np.sin(q1))/10000 + (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2))))/10000 - (853*np.cos(q1)*np.cos(q2)*np.cos(q3))/4000 + (853*np.cos(q1)*np.sin(q2)*np.sin(q3))/4000
    JA22 = float (4873*np.sin(q1)*np.sin(q2))/20000 - (1707*np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000 - (1707*np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)) - np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1))))/10000 + (853*np.cos(q2)*np.sin(q1)*np.sin(q3))/4000 + (853*np.cos(q3)*np.sin(q1)*np.sin(q2))/4000
    JA23 = float (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)) - np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1))))/10000 - (1707*np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 - (1707*np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000 + (853*np.cos(q2)*np.sin(q1)*np.sin(q3))/4000 + (853*np.cos(q3)*np.sin(q1)*np.sin(q2))/4000
    JA24 = float (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)) - np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1))))/10000 - (1707*np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 - (1707*np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000
    JA25 = float (819*np.cos(q1)*np.sin(q5))/10000 + (819*np.cos(q5)*(np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)) + np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2))))/10000
    JA26 = 0
    JA31 = 0
    JA32 = float (853*np.sin(q2)*np.sin(q3))/4000 - (853*np.cos(q2)*np.cos(q3))/4000 - (4873*np.cos(q2))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2))))/10000 + (1707*np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)))/20000
    JA33 = float (853*np.sin(q2)*np.sin(q3))/4000 - (853*np.cos(q2)*np.cos(q3))/4000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2))))/10000 + (1707*np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)))/20000
    JA34 = float (1707*np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2))))/10000 + (1707*np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)))/20000
    JA35 = float (-(819*np.cos(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3))))/10000)
    JA36 = 0
    JA41 = 0 
    JA42 = np.sin(q1)
    JA43 = np.sin(q1)
    JA44 = np.sin(q1)
    JA45 = np.cos(q1)*np.cos(q2)*np.cos(q3)*np.sin(q4) + np.cos(q1)*np.cos(q2)*np.cos(q4)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.cos(q4)*np.sin(q2) - np.cos(q1)*np.sin(q2)*np.sin(q3)*np.sin(q4)  
    JA46 = np.cos(q5)*np.sin(q1) - np.cos(q1)*np.cos(q2)*np.cos(q3)*np.cos(q4)*np.sin(q5) + np.cos(q1)*np.cos(q2)*np.sin(q3)*np.sin(q4)*np.sin(q5) + np.cos(q1)*np.cos(q3)*np.sin(q2)*np.sin(q4)*np.sin(q5) + np.cos(q1)*np.cos(q4)*np.sin(q2)*np.sin(q3)*np.sin(q5)
    JA51 = 0
    JA52 = -np.cos(q1)
    JA53 = -np.cos(q1)
    JA54 = -np.cos(q1)
    JA55 = np.cos(q2)*np.cos(q3)*np.sin(q1)*np.sin(q4) + np.cos(q2)*np.cos(q4)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.cos(q4)*np.sin(q1)*np.sin(q2) - np.sin(q1)*np.sin(q2)*np.sin(q3)*np.sin(q4)
    JA56 = np.cos(q2)*np.sin(q1)*np.sin(q3)*np.sin(q4)*np.sin(q5) - np.cos(q2)*np.cos(q3)*np.cos(q4)*np.sin(q1)*np.sin(q5) - np.cos(q1)*np.cos(q5) + np.cos(q3)*np.sin(q1)*np.sin(q2)*np.sin(q4)*np.sin(q5) + np.cos(q4)*np.sin(q1)*np.sin(q2)*np.sin(q3)*np.sin(q5)
    JA61 = 1
    JA62 = 0 
    JA63 = 0 
    JA64 = 0 
    JA65 = -np.cos(q2 + q3 + q4) 
    JA66 = np.cos(q2 + q3 + q4 + q5)/2 - np.cos(q2 + q3 + q4 - q5)/2
    JA = np.matrix([[JA11,JA12,JA13,JA14,JA15,JA16],[JA21,JA22,JA23,JA24,JA25,JA26],[JA31,JA32,JA33,JA34,JA35,JA36],[JA41,JA42,JA43,JA44,JA45,JA46],[JA51,JA52,JA53,JA54,JA55,JA56],[JA61,JA62,JA63,JA64,JA65,JA66]])
    return (JA)

def pos_rob(q1,q2,q3,q4,q5,q6):
    x = (2247*np.sin(q1))/20000 - (4873*np.cos(q1)*np.cos(q2))/20000 + (819*np.cos(q5)*np.sin(q1))/10000 + (1707*np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2)))/20000 + (1707*np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)))/20000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q1)*np.cos(q2)*np.cos(q3) - np.cos(q1)*np.sin(q2)*np.sin(q3)) - np.sin(q4)*(np.cos(q1)*np.cos(q2)*np.sin(q3) + np.cos(q1)*np.cos(q3)*np.sin(q2))))/10000 - (853*np.cos(q1)*np.cos(q2)*np.cos(q3))/4000 + (853*np.cos(q1)*np.sin(q2)*np.sin(q3))/4000
    y = (1707*np.cos(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2)))/20000 - (819*np.cos(q1)*np.cos(q5))/10000 - (4873*np.cos(q2)*np.sin(q1))/20000 - (2247*np.cos(q1))/20000 - (1707*np.sin(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)))/20000 + (819*np.sin(q5)*(np.cos(q4)*(np.sin(q1)*np.sin(q2)*np.sin(q3) - np.cos(q2)*np.cos(q3)*np.sin(q1)) + np.sin(q4)*(np.cos(q2)*np.sin(q1)*np.sin(q3) + np.cos(q3)*np.sin(q1)*np.sin(q2))))/10000 + (853*np.sin(q1)*np.sin(q2)*np.sin(q3))/4000 - (853*np.cos(q2)*np.cos(q3)*np.sin(q1))/4000
    z = (1707*np.sin(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)))/20000 - (853*np.cos(q2)*np.sin(q3))/4000 - (853*np.cos(q3)*np.sin(q2))/4000 - (819*np.sin(q5)*(np.cos(q4)*(np.cos(q2)*np.sin(q3) + np.cos(q3)*np.sin(q2)) + np.sin(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3))))/10000 - (1707*np.cos(q4)*(np.cos(q2)*np.cos(q3) - np.sin(q2)*np.sin(q3)))/20000 - (4873*np.sin(q2))/20000 + 1519/10000
    h = [float(x),float(y),float(z)]
    return h

interval = True



try:
    rob = urx.Robot("192.168.88.249")
except:
    print('robot error')
    interval = False


if interval:


    #Controller
    dt = 0.1


    print('1')
    P = np.array([0.2,0.2,0.2]).reshape(3,1);
    V = np.array([0.8,0.07,0.2]).reshape(3,1)
    Po = np.array([2.1,2.1,10.1]).reshape(3,1);
    e = np.zeros((3,1));
    lamda = 0.01
    k2 = (np.diag([1.2,2.3,3.3]));
    k1 = ( np.diag([1.1,2.3,1.3]));

    while True:
        
        if keyboard.is_pressed('q'):  # if key 'q' is pressed 
            print('You Pressed A Key!')
            break  # finishing the loop

        try :
            with open('data2.json', 'r') as fa:
                data = json.load(fa)
                k1[0,0] = data['controller']['k11']
                k1[1,1] = data['controller']['k12']
                k1[2,2] = data['controller']['k13']
                k2[0,0] = data['controller']['k21']
                k2[1,1] = data['controller']['k22']
                k2[2,2] = data['controller']['k23']                
                vmax = data['controller']['vmax']
                x_refr = data['poss']['xref']
                y_refr = data['poss']['yref']
                z_refr = data['poss']['zref']


                
        except:
            print('file error')


        t = rob.get_pose()
        print("Transformation from base to tcp is: ", t)


        pose = rob.getl()
        xn = float(pose[0])
        yn = float(pose[1])
        zn = float(pose[2])
        P = np.zeros((3,1));
        P[0,0] = float(xn)
        P[1,0] = float(yn)
        P[2,0] = float(zn)
        print('Punto actual',P)
        
        Po = np.zeros((3,1));   
        Po[0,0] = float(x_refr)
        Po[1,0] = float(y_refr)
        Po[2,0] = float(z_refr)
        print('punto deseado',Po)
        
        e = Po - P      
        hv = np.matmul(k2,np.tanh(np.matmul(k1,e)))
        print(k1,k2)
        vx1 = hv[0,0]
        vy1 = hv[1,0]
        vz1 = hv[2,0]
        
        if (vx1 > vmax):
            vx1 = vmax;
        elif (vx1 < -vmax):
            vx1 = -vmax;

        if (vy1 > vmax):
            vy1 = vmax;
        elif (vy1 < -vmax):
            vy1 = -vmax;

        if (vz1 > vmax):
            vz1 = vmax;
        elif (vz1 < -vmax):
            vz1 = -vmax;


        V[0,0] = vx1
        V[1,0] = vy1
        V[2,0] = vz1

        print ('velocidad',vx1,vy1,vz1) 

        J = rob.getj()
        print(J)
        JA = Jacobian(J[0],J[1],J[2],J[3],J[4],J[5])
        JAp = JA.transpose();
        JA1 = JA * JAp + np.eye(6)*lamda
        J2 = inv(JA1)*JA
        C = J2.transpose()*np.matrix(([[vx1],[vy1],[vz1],[0],[0],[0]]))
        print(C)
        J = [float(C[0,0]), float(C[1,0]), float(C[2,0]), float(C[3,0]), float(C[4,0]), float(C[5,0])]
        try:
            rob.speedj(J,acc=0.02, min_time=3)
        except:
            print('sent')

        time.sleep(0.01)



else:
    print('finishing')
    try:
        rob.stopl()
    except:
        print('No')
# Out:
# tried 11 times to find a packet in data, advertised packet size: -2, type: 3
# Data length: 68
# tried 11 times to find a packet in data, advertised packet size: -2, type: 3
# Data length: 1092
# tried 11 times to find a packet in data, advertised packet size: -2, type: 3
# Data length: 1418
# 1
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18941696,  0.16538292,  0.96786864],
#        [ 0.47671273,  0.87723504, -0.05660088],
#        [-0.8584091 ,  0.45067414, -0.24500334]])>
# <Vector: (0.44507, -0.13328, 0.39008)>
# >
# Punto actual [[ 0.4450666 ]
#  [-0.13328334]
#  [ 0.39008493]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.14112870635613106 0.1302136221779285 0.009913774941902341
# [-0.04342633882631475, -2.173473660145895, -1.088372532521383, -0.12683135667909795, -4.722361270581381, 20.911595773681093]
# [[ 0.23879115]
#  [ 0.48075995]
#  [-0.62019299]
#  [ 0.13936086]
#  [-0.22645841]
#  [ 0.05782275]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18943021,  0.16533533,  0.96787418],
#        [ 0.47670304,  0.87724332, -0.05655421],
#        [-0.85841156,  0.45067548, -0.24499224]])>
# <Vector: (0.44508, -0.13326, 0.39008)>
# >
# Punto actual [[ 0.44507618]
#  [-0.13326202]
#  [ 0.39007512]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1411375205792653 0.13019374370102263 0.0099235757610818
# [-0.04337817827333623, -2.173497502003805, -1.0883849302874964, -0.12678367296327764, -4.722361270581381, 20.911595773681093]
# [[ 0.23876003]
#  [ 0.48076261]
#  [-0.62018029]
#  [ 0.13934614]
#  [-0.22642939]
#  [ 0.05781259]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18937886,  0.16530811,  0.96788887],
#        [ 0.4766982 ,  0.87724587, -0.05655535],
#        [-0.85842558,  0.4506805 , -0.24493391]])>
# <Vector: (0.44507, -0.13326, 0.39010)>
# >
# Punto actual [[ 0.44506621]
#  [-0.1332572 ]
#  [ 0.39010301]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1411283393746885 0.13018925193924896 0.009895700381489111
# [-0.043366257344381154, -2.1734498182879847, -1.088360611592428, -0.12679559389223272, -4.722373310719625, 20.911595773681093]
# [[ 0.23876037]
#  [ 0.48070978]
#  [-0.62016951]
#  [ 0.13938695]
#  [-0.2264332 ]
#  [ 0.05779891]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18942294,  0.16532202,  0.96787787],
#        [ 0.47671352,  0.87723837, -0.05654261],
#        [-0.85840735,  0.45069   , -0.24498032]])>
# <Vector: (0.44506, -0.13326, 0.39009)>
# >
# Punto actual [[ 0.44506471]
#  [-0.13326058]
#  [ 0.39009478]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.14112696029624971 0.13019240026949133 0.009903928892862
# [-0.04337817827333623, -2.1734378973590296, -1.0883963743792933, -0.12681943575014287, -4.722349349652426, 20.911607694610048]
# [[ 0.23876556]
#  [ 0.48072231]
#  [-0.62015966]
#  [ 0.13936573]
#  [-0.22643535]
#  [ 0.05781109]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18950451,  0.16534433,  0.9678581 ],
#        [ 0.47668644,  0.87725378, -0.05653175],
#        [-0.85840438,  0.45065181, -0.24506095]])>
# <Vector: (0.44504, -0.13324, 0.39009)>
# >
# Punto actual [[ 0.44503958]
#  [-0.13324118]
#  [ 0.39008685]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.14110383530154855 0.1301743158266541 0.009911853841131435
# [-0.04333049455751592, -2.173269573842184, -1.0886719862567347, -0.12679559389223272, -4.72238523164858, 20.911583852752138]
# [[ 0.23877405]
#  [ 0.4806741 ]
#  [-0.62003181]
#  [ 0.13928329]
#  [-0.22643934]
#  [ 0.05783228]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18949139,  0.16533915,  0.96786155],
#        [ 0.47666922,  0.87726272, -0.05653821],
#        [-0.85841684,  0.45063631, -0.24504582]])>
# <Vector: (0.44500, -0.13316, 0.39012)>
# >
# Punto actual [[ 0.44499842]
#  [-0.13315571]
#  [ 0.39011731]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.14106595031543623 0.13009463571202073 0.009881404152616588
# [-0.043102566395894826, -2.1729334036456507, -1.0890901724444788, -0.1266997496234339, -4.722612206135885, 20.911619853957582]
# [[ 0.23873349]
#  [ 0.48048528]
#  [-0.61977818]
#  [ 0.13920422]
#  [-0.22640336]
#  [ 0.05781932]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.1895132 ,  0.16541856,  0.96784371],
#        [ 0.47665095,  0.87726834, -0.05660503],
#        [-0.85842217,  0.45059622, -0.24510085]])>
# <Vector: (0.44493, -0.13307, 0.39012)>
# >
# Punto actual [[ 0.44492954]
#  [-0.13307008]
#  [ 0.39012191]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1410025480707725 0.13001480576795696 0.009876801299087922
# [-0.04286319414247686, -2.1724537054644983, -1.089832607899801, -0.12649614015688115, -4.7229114214526575, 20.911655616744447]
# [[ 0.23873026]
#  [ 0.48028018]
#  [-0.61940534]
#  [ 0.13901819]
#  [-0.22639973]
#  [ 0.05783212]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18939786,  0.16546826,  0.96785779],
#        [ 0.47672041,  0.87722542, -0.05668512],
#        [-0.85840905,  0.45066152, -0.24502671]])>
# <Vector: (0.44480, -0.13298, 0.39021)>
# >
# Punto actual [[ 0.4448019 ]
#  [-0.13297851]
#  [ 0.39020872]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1408850535453915 0.1299294165982164 0.009790024658499702
# [-0.04261142412294561, -2.171697441731588, -1.0907061735736292, -0.1263049284564417, -4.723234240208761, 20.911799859984804]
# [[ 0.23876521]
#  [ 0.47988243]
#  [-0.61891755]
#  [ 0.13890623]
#  [-0.2264406 ]
#  [ 0.05782372]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18907824,  0.16536134,  0.96793856],
#        [ 0.47674146,  0.87721081, -0.0567343 ],
#        [-0.85846782,  0.45072921, -0.24469608]])>
# <Vector: (0.44465, -0.13285, 0.39038)>
# >
# Punto actual [[ 0.44464921]
#  [-0.1328522 ]
#  [ 0.39037918]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.140744478751701 0.12981163180913696 0.009619629256315938
# [-0.04227620760072881, -2.170821015034811, -1.0915082136737269, -0.12604123750795537, -4.723604623471395, 20.91191978453009]
# [[ 0.23877394]
#  [ 0.47930743]
#  [-0.61838682]
#  [ 0.13892533]
#  [-0.22647178]
#  [ 0.05774843]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.1891521 ,  0.16542598,  0.96791308],
#        [ 0.47677696,  0.87719065, -0.05674762],
#        [-0.85843184,  0.45074472, -0.24479375]])>
# <Vector: (0.44450, -0.13268, 0.39042)>
# >
# Punto actual [[ 0.44450107]
#  [-0.13267974]
#  [ 0.39042436]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1406080642116544 0.12965078671742572 0.009574465706029012
# [-0.04182130495180303, -2.1698125044452112, -1.0929082075702112, -0.1257541815387171, -4.724058930073873, 20.912064266189027]
# [[ 0.23875843]
#  [ 0.47884279]
#  [-0.61764081]
#  [ 0.13861426]
#  [-0.2264558 ]
#  [ 0.05776873]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18936702,  0.16540553,  0.96787455],
#        [ 0.47675603,  0.87720945, -0.05663278],
#        [-0.85839607,  0.45071565, -0.24497262]])>
# <Vector: (0.44438, -0.13244, 0.39045)>
# >
# Punto actual [[ 0.44437518]
#  [-0.13244464]
#  [ 0.39044548]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.14049212298034425 0.1294314666226392 0.009553360883784808
# [-0.041222397481099904, -2.16880447069277, -1.0943802038775843, -0.12547856966127569, -4.7245251576053064, 20.91217226980536]
# [[ 0.23865746]
#  [ 0.47837862]
#  [-0.61683053]
#  [ 0.13823805]
#  [-0.22635362]
#  [ 0.05778758]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18907255,  0.16549394,  0.967917  ],
#        [ 0.47674575,  0.8772006 , -0.05685595],
#        [-0.85846669,  0.45070042, -0.24475309]])>
# <Vector: (0.44416, -0.13224, 0.39060)>
# >
# Punto actual [[ 0.4441553 ]
#  [-0.13223818]
#  [ 0.39059871]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.14028957643435994 0.12923881668500783 0.009400179616341086
# [-0.04063588777651006, -2.167447868977682, -1.0959962050067347, -0.12499934831728154, -4.725314323102133, 20.912316274627138]
# [[ 0.23867761]
#  [ 0.47762777]
#  [-0.61591106]
#  [ 0.13801952]
#  [-0.22639238]
#  [ 0.05774232]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18923356,  0.16530937,  0.96791708],
#        [ 0.47681324,  0.87718093, -0.05659282],
#        [-0.85839373,  0.45080641, -0.24481377]])>
# <Vector: (0.44394, -0.13192, 0.39072)>
# >
# Punto actual [[ 0.44394481]
#  [-0.13192174]
#  [ 0.39071607]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.14009563495865476 0.12894346657559372 0.009282867761852063
# [-0.03985721269716436, -2.1659353415118616, -1.0978987852679651, -0.12467605272401983, -4.725804511700765, 20.912568283065248]
# [[ 0.23855287]
#  [ 0.47683529]
#  [-0.61478642]
#  [ 0.13765302]
#  [-0.22627541]
#  [ 0.05772765]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18923339,  0.16520103,  0.96793561],
#        [ 0.47670384,  0.8772447 , -0.05652591],
#        [-0.85845452,  0.45072204, -0.24475596]])>
# <Vector: (0.44371, -0.13157, 0.39086)>
# >
# Punto actual [[ 0.44371089]
#  [-0.13156808]
#  [ 0.39085622]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1398800469254755 0.1286132730468876 0.009142757145577647
# [-0.03893500963319951, -2.164266888295309, -1.1000054518329065, -0.12418538728822881, -4.726629559193746, 20.912664365752626]
# [[ 0.2384281 ]
#  [ 0.47593001]
#  [-0.6135444 ]
#  [ 0.1372633 ]
#  [-0.22616724]
#  [ 0.05768578]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18916387,  0.1652487 ,  0.96794106],
#        [ 0.47675477,  0.87721304, -0.05658768],
#        [-0.85844157,  0.45076617, -0.24472012]])>
# <Vector: (0.44346, -0.13125, 0.39100)>
# >
# Punto actual [[ 0.44345587]
#  [-0.13125125]
#  [ 0.39100177]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13964495303128896 0.12831735151822393 0.008997259334192147
# [-0.03808433214296514, -2.1625383535968226, -1.1021717230426233, -0.12371856371034795, -4.727514211331503, 20.91292829511969]
# [[ 0.23836648]
#  [ 0.47502143]
#  [-0.61229605]
#  [ 0.13686647]
#  [-0.22611836]
#  [ 0.05766463]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.189372  ,  0.16522527,  0.96790436],
#        [ 0.4767276 ,  0.87723506, -0.05647515],
#        [-0.85841077,  0.45073191, -0.2448912 ]])>
# <Vector: (0.44317, -0.13085, 0.39110)>
# >
# Punto actual [[ 0.44316731]
#  [-0.13085405]
#  [ 0.39109514]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1393788621465486 0.12794623760700163 0.008903916760209303
# [-0.03705484071840459, -2.1605094114886683, -1.1049721876727503, -0.1231315771685999, -4.728399101887838, 20.913132381423402]
# [[ 0.23825635]
#  [ 0.47403599]
#  [-0.61073555]
#  [ 0.13623407]
#  [-0.22601195]
#  [ 0.05768067]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18936829,  0.1652527 ,  0.96790041],
#        [ 0.47672193,  0.87723632, -0.05650339],
#        [-0.85841473,  0.4507194 , -0.24490033]])>
# <Vector: (0.44287, -0.13050, 0.39124)>
# >
# Punto actual [[ 0.44287258]
#  [-0.13050358]
#  [ 0.39124179]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1391069862373757 0.1276186639342425 0.008757316741819132
# [-0.036120239888326466, -2.1585410276996058, -1.107497517262594, -0.12259275117983037, -4.729331676159994, 20.913348865493226]
# [[ 0.23819518]
#  [ 0.47302308]
#  [-0.60929372]
#  [ 0.13574476]
#  [-0.22596153]
#  [ 0.05767056]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18928769,  0.16522004,  0.96792175],
#        [ 0.47670993,  0.87724206, -0.05651557],
#        [-0.85843917,  0.45072021, -0.24481316]])>
# <Vector: (0.44252, -0.13007, 0.39145)>
# >
# Punto actual [[ 0.44251957]
#  [-0.13007166]
#  [ 0.39144704]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13878123327919847 0.12721479385535003 0.008552128106141648
# [-0.03497058549989873, -2.1561883131610315, -1.11041766801943, -0.12194615999330694, -4.730455581341879, 20.913612794860292]
# [[ 0.23810002]
#  [ 0.47175929]
#  [-0.60758059]
#  [ 0.13522292]
#  [-0.22588585]
#  [ 0.05763019]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18937607,  0.16511381,  0.96792259],
#        [ 0.47672197,  0.87724464, -0.0563738 ],
#        [-0.85841299,  0.45075411, -0.24484253]])>
# <Vector: (0.44220, -0.12960, 0.39158)>
# >
# Punto actual [[ 0.44219882]
#  [-0.12960299]
#  [ 0.39158161]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1384851481213658 0.1267763529149009 0.008417594961306785
# [-0.03374940553774053, -2.153942886983053, -1.113434139882223, -0.12121564546693975, -4.731495920811788, 20.91391296385138]
# [[ 0.23793511]
#  [ 0.47058639]
#  [-0.60583478]
#  [ 0.1345843 ]
#  [-0.22573636]
#  [ 0.05760028]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18942653,  0.16505501,  0.96792274],
#        [ 0.47668303,  0.87727005, -0.05630759],
#        [-0.85842348,  0.45072619, -0.24485715]])>
# <Vector: (0.44180, -0.12909, 0.39178)>
# >
# Punto actual [[ 0.44180477]
#  [-0.12909095]
#  [ 0.39177954]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13812124961743563 0.12629711230930876 0.008219719436048918
# [-0.03239566484560186, -2.1512659231769007, -1.116856877003805, -0.12049752870668584, -4.732739631329672, 20.9141888141474]
# [[ 0.23779211]
#  [ 0.46917553]
#  [-0.60382773]
#  [ 0.13390813]
#  [-0.22561014]
#  [ 0.057573  ]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18940807,  0.16496841,  0.96794112],
#        [ 0.47671633,  0.87725703, -0.0562284 ],
#        [-0.85840906,  0.45078323, -0.24480269]])>
# <Vector: (0.44142, -0.12860, 0.39197)>
# >
# Punto actual [[ 0.44141762]
#  [-0.128597  ]
#  [ 0.39196512]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13776356000632478 0.1258345610608701 0.008034187375463919
# [-0.031090561543599904, -2.1486857573138636, -1.1202076117144983, -0.1196830908404749, -4.733923141156332, 20.914537620528627]
# [[ 0.23765547]
#  [ 0.46779956]
#  [-0.60186789]
#  [ 0.1332494 ]
#  [-0.22549356]
#  [ 0.05753096]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18946515,  0.16497445,  0.96792892],
#        [ 0.47676914,  0.87723069, -0.05619164],
#        [-0.85836714,  0.45083228, -0.24485937]])>
# <Vector: (0.44099, -0.12801, 0.39216)>
# >
# Punto actual [[ 0.44098939]
#  [-0.12801064]
#  [ 0.39216457]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13736775203864687 0.1252851791593788 0.007834783895624963
# [-0.02952129045595342, -2.1457322279559534, -1.124038044606344, -0.11888057390321904, -4.735405389462606, 20.91496939657538]
# [[ 0.23746782]
#  [ 0.46624306]
#  [-0.59960744]
#  [ 0.13245176]
#  [-0.22532366]
#  [ 0.05750394]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18945666,  0.16499867,  0.96792645],
#        [ 0.47671195,  0.87725906, -0.05623395],
#        [-0.85840078,  0.45076821, -0.24485941]])>
# <Vector: (0.44055, -0.12750, 0.39238)>
# >
# Punto actual [[ 0.44054845]
#  [-0.12750196]
#  [ 0.39237623]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13695998993039507 0.1248083149032132 0.007623182235419028
# [-0.028144184743062794, -2.1428516546832483, -1.1277120749102991, -0.11810237566103154, -4.736780230198995, 20.915233325942445]
# [[ 0.23736587]
#  [ 0.46472658]
#  [-0.59745267]
#  [ 0.13172591]
#  [-0.22523803]
#  [ 0.05748422]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18943479,  0.16500532,  0.9679296 ],
#        [ 0.47672077,  0.87725338, -0.05624786],
#        [-0.8584007 ,  0.45077684, -0.24484377]])>
# <Vector: (0.44005, -0.12690, 0.39262)>
# >
# Punto actual [[ 0.44004706]
#  [-0.12690394]
#  [ 0.39261626]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13649609342408747 0.12424738311350352 0.00738320550340902
# [-0.026527229939595998, -2.139562431965963, -1.1319130102740687, -0.11719257036317998, -4.738358799611227, 20.915629577620912]
# [[ 0.2372221 ]
#  [ 0.46297594]
#  [-0.5949664 ]
#  [ 0.13089047]
#  [-0.22511493]
#  [ 0.0574517 ]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18949599,  0.1650029 ,  0.96791803],
#        [ 0.47673233,  0.87724931, -0.05621324],
#        [-0.85838077,  0.45078564, -0.24489744]])>
# <Vector: (0.43957, -0.12630, 0.39281)>
# >
# Punto actual [[ 0.43956662]
#  [-0.12630456]
#  [ 0.39280753]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13605134619026116 0.1236848556876599 0.0071919744565312384
# [-0.024910751973287404, -2.136380974446432, -1.1361258665667933, -0.1162346045123499, -4.739888970051901, 20.91602582929938]
# [[ 0.23705504]
#  [ 0.46130667]
#  [-0.59249045]
#  [ 0.12998828]
#  [-0.22496515]
#  [ 0.05742988]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18952292,  0.16488576,  0.96793272],
#        [ 0.476754  ,  0.87724555, -0.05608808],
#        [-0.85836279,  0.45083582, -0.24486808]])>
# <Vector: (0.43900, -0.12564, 0.39307)>
# >
# Punto actual [[ 0.43899676]
#  [-0.12564119]
#  [ 0.3930716 ]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13552351273955052 0.1230618729025985 0.00692795687175616
# [-0.023137871419088185, -2.1327083746539515, -1.1408174673663538, -0.11520463625063115, -4.741479102765219, 20.916470003112245]
# [[ 0.23688161]
#  [ 0.45933143]
#  [-0.58968255]
#  [ 0.12905498]
#  [-0.22481499]
#  [ 0.0573876 ]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18937669,  0.16489372,  0.96795998],
#        [ 0.47675176,  0.87724181, -0.05616554],
#        [-0.85839631,  0.45084018, -0.24474253]])>
# <Vector: (0.43846, -0.12501, 0.39333)>
# >
# Punto actual [[ 0.43846356]
#  [-0.12500628]
#  [ 0.393334  ]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13502933747623388 0.12246523220274402 0.006665600198553432
# [-0.021389309559957326, -2.1292627493487757, -1.1451857725726526, -0.1141746679889124, -4.74324864545931, 20.916890096648622]
# [[ 0.23671195]
#  [ 0.45743787]
#  [-0.58704379]
#  [ 0.1282008 ]
#  [-0.22467408]
#  [ 0.05732471]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18951591,  0.16487718,  0.96793555],
#        [ 0.47675681,  0.87724436, -0.05608284],
#        [-0.85836278,  0.45084127, -0.24485809]])>
# <Vector: (0.43787, -0.12426, 0.39357)>
# >
# Punto actual [[ 0.4378733 ]
#  [-0.12426485]
#  [ 0.39356923]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13448195349441752 0.12176803251823598 0.006430414244214582
# [-0.019377056752340138, -2.1253612677203577, -1.1502841154681605, -0.1131213347064417, -4.745113794003622, 20.91737074850409]
# [[ 0.23647285]
#  [ 0.45536423]
#  [-0.58397585]
#  [ 0.12709034]
#  [-0.22445394]
#  [ 0.05730238]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18948638,  0.1647969 ,  0.96795501],
#        [ 0.47678461,  0.8772335 , -0.05601621],
#        [-0.85835386,  0.45089174, -0.24479643]])>
# <Vector: (0.43724, -0.12348, 0.39384)>
# >
# Punto actual [[ 0.43724199]
#  [-0.12348407]
#  [ 0.39384158]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1338961173941862 0.12103328036515776 0.006158109536169799
# [-0.01724559465517217, -2.121268097554342, -1.155586067830221, -0.11187583604921514, -4.747110191975729, 20.917910766585756]
# [[ 0.23621605]
#  [ 0.45311983]
#  [-0.58075001]
#  [ 0.12598705]
#  [-0.22422785]
#  [ 0.05723522]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18943744,  0.16469555,  0.96798183],
#        [ 0.47671092,  0.87727658, -0.05596867],
#        [-0.85840559,  0.45084495, -0.2447012 ]])>
# <Vector: (0.43661, -0.12277, 0.39413)>
# >
# Punto actual [[ 0.43660888]
#  [-0.12276796]
#  [ 0.39413475]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13330821131109302 0.12035889507580803 0.005864977918728561
# [-0.015281502400533498, -2.1172707716571253, -1.1606367270099085, -0.11075002351869756, -4.748963300381796, 20.918295335753847]
# [[ 0.23601461]
#  [ 0.45091233]
#  [-0.57765229]
#  [ 0.12498267]
#  [-0.22405539]
#  [ 0.05717342]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18943575,  0.16468726,  0.96798358],
#        [ 0.476663  ,  0.87730218, -0.05597561],
#        [-0.85843257,  0.45079817, -0.24469272]])>
# <Vector: (0.43591, -0.12198, 0.39441)>
# >
# Punto actual [[ 0.43591409]
#  [-0.12197757]
#  [ 0.39440993]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13266257116166802 0.11961402038836114 0.005589836454500497
# [-0.013089958821431935, -2.1128767172442835, -1.1663458983050745, -0.10945684114565069, -4.751091663037435, 20.918763589843202]
# [[ 0.23579097]
#  [ 0.44852429]
#  [-0.57417844]
#  [ 0.12376712]
#  [-0.2238583 ]
#  [ 0.05712837]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18953677,  0.16471907,  0.96795839],
#        [ 0.47675077,  0.87725731, -0.05593134],
#        [-0.85836153,  0.45087386, -0.24480246]])>
# <Vector: (0.43526, -0.12122, 0.39464)>
# >
# Punto actual [[ 0.43525566]
#  [-0.12121664]
#  [ 0.39464318]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13205027672028755 0.11889638006815727 0.005356618561353821
# [-0.01098186174501592, -2.108687225972311, -1.1718514601336878, -0.108283821736471, -4.753088061009542, 20.91936345098822]
# [[ 0.23555644]
#  [ 0.44627369]
#  [-0.57082156]
#  [ 0.12253884]
#  [-0.22364282]
#  [ 0.05710806]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18935403,  0.16461538,  0.96801179],
#        [ 0.4767214 ,  0.87727318, -0.05593273],
#        [-0.85841817,  0.45088085, -0.24459089]])>
# <Vector: (0.43447, -0.12036, 0.39501)>
# >
# Punto actual [[ 0.43447261]
#  [-0.12035984]
#  [ 0.39500671]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13132154825314057 0.11808770519913293 0.004993121221246093
# [-0.008586708699361623, -2.10384971300234, -1.1779077688800257, -0.10688239732851201, -4.755407754574911, 20.919903945907045]
# [[ 0.23530356]
#  [ 0.44353721]
#  [-0.56703545]
#  [ 0.12134954]
#  [-0.22343021]
#  [ 0.05701064]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18928697,  0.16453536,  0.96803851],
#        [ 0.4767516 ,  0.8772599 , -0.05588353],
#        [-0.85841619,  0.45093589, -0.24449637]])>
# <Vector: (0.43374, -0.11953, 0.39530)>
# >
# Punto actual [[ 0.43374186]
#  [-0.11952903]
#  [ 0.39530037]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.13064094199003926 0.1173029265252167 0.004699493765561624
# [-0.006263558064595998, -2.099299732838766, -1.1837599913226526, -0.10551768938173467, -4.757607642804281, 20.92049212454169]
# [[ 0.23502487]
#  [ 0.44098935]
#  [-0.56338545]
#  [ 0.12011631]
#  [-0.22318505]
#  [ 0.05693417]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18939401,  0.16445837,  0.96803066],
#        [ 0.47680664,  0.87723867, -0.05574712],
#        [-0.85836201,  0.45100527, -0.2445586 ]])>
# <Vector: (0.43295, -0.11859, 0.39559)>
# >
# Punto actual [[ 0.43295201]
#  [-0.11858922]
#  [ 0.39558691]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.12990470556186623 0.11641445104948724 0.0044129757090300625
# [-0.003640476857320607, -2.094306294118063, -1.1902464071856897, -0.10412866273988897, -4.760010544453756, 20.92117638586371]
# [[ 0.23466249]
#  [ 0.43822007]
#  [-0.5593167 ]
#  [ 0.11867332]
#  [-0.222852  ]
#  [ 0.05687578]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18937567,  0.16445917,  0.96803411],
#        [ 0.47675258,  0.87726647, -0.05577198],
#        [-0.85839608,  0.45095091, -0.24453926]])>
# <Vector: (0.43216, -0.11774, 0.39588)>
# >
# Punto actual [[ 0.43215754]
#  [-0.11773922]
#  [ 0.39587855]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.12916356192036996 0.11561021405267895 0.004121357137590149
# [-0.0012210051165979507, -2.0894439856158655, -1.1965182463275355, -0.10273963609804326, -4.762377802525656, 20.921692562087465]
# [[ 0.23439846]
#  [ 0.43551591]
#  [-0.55539114]
#  [ 0.11731107]
#  [-0.22261678]
#  [ 0.05682261]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18944136,  0.16444749,  0.96802324],
#        [ 0.47676775,  0.87726116, -0.05572579],
#        [-0.85837316,  0.4509655 , -0.24459281]])>
# <Vector: (0.43128, -0.11675, 0.39620)>
# >
# Punto actual [[ 0.43127673]
#  [-0.11675415]
#  [ 0.39619511]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1283411587277106 0.11467737984315023 0.0038048179649542435
# [0.0015807942254468799, -2.083994213734762, -1.203531567250387, -0.10127860704530889, -4.765043918286459, 20.922377061828065]
# [[ 0.23403704]
#  [ 0.43247212]
#  [-0.55094992]
#  [ 0.11575538]
#  [-0.22228582]
#  [ 0.05676545]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18933365,  0.16430283,  0.96806888],
#        [ 0.47676002,  0.87727029, -0.05564818],
#        [-0.85840122,  0.45100046, -0.24442981]])>
# <Vector: (0.43044, -0.11584, 0.39653)>
# >
# Punto actual [[ 0.43043508]
#  [-0.11583849]
#  [ 0.39653459]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.12755462311791407 0.1138095246002913 0.003465354126741121
# [0.004191857296973467, -2.078892532979147, -1.209970776234762, -0.09981757799257451, -4.767494622861044, 20.922989320739198]
# [[ 0.23369332]
#  [ 0.42953414]
#  [-0.54681464]
#  [ 0.11441543]
#  [-0.22198255]
#  [ 0.05666153]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18937245,  0.16432217,  0.968058  ],
#        [ 0.47682782,  0.87723472, -0.05562793],
#        [-0.858355  ,  0.45106259, -0.24447748]])>
# <Vector: (0.42950, -0.11483, 0.39682)>
# >
# Punto actual [[ 0.42949668]
#  [-0.11483371]
#  [ 0.39682352]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1266768732862311 0.11285636663818875 0.0031764381699695343
# [0.0070901671424508095, -2.073214356099264, -1.2174151579486292, -0.09815341631044561, -4.770280663167135, 20.92375798223822]
# [[ 0.23332896]
#  [ 0.42635667]
#  [-0.54209661]
#  [ 0.1127127 ]
#  [-0.22164906]
#  [ 0.05660454]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18936758,  0.16426039,  0.96806944],
#        [ 0.47685032,  0.8772263 , -0.05556786],
#        [-0.85834357,  0.45110147, -0.24444585]])>
# <Vector: (0.42858, -0.11388, 0.39715)>
# >
# Punto actual [[ 0.42857589]
#  [-0.11387753]
#  [ 0.39714986]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.12581479073079968 0.11194851522511509 0.00285010472623638
# [0.009856276214122772, -2.067704502736227, -1.2244284788714808, -0.09666854539980108, -4.772898737584249, 20.924441766723085]
# [[ 0.23297576]
#  [ 0.42321625]
#  [-0.53757853]
#  [ 0.11118256]
#  [-0.22132936]
#  [ 0.05653149]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18940763,  0.16414272,  0.96808157],
#        [ 0.47687322,  0.87722222, -0.05543564],
#        [-0.85832201,  0.45115224, -0.24442785]])>
# <Vector: (0.42757, -0.11278, 0.39746)>
# >
# Punto actual [[ 0.42757018]
#  [-0.1127817 ]
#  [ 0.39745848]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.12487227820690046 0.11090710395091662 0.0025415025924927274
# [0.013029849156737328, -2.0616658369647425, -1.2323039213763636, -0.09487277666200811, -4.775839749966757, 20.925222349151063]
# [[ 0.23251034]
#  [ 0.41976176]
#  [-0.53249641]
#  [ 0.10938762]
#  [-0.22090313]
#  [ 0.05643755]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18917657,  0.16400008,  0.96815092],
#        [ 0.47683557,  0.87724322, -0.05542715],
#        [-0.85839389,  0.45116327, -0.24415493]])>
# <Vector: (0.42658, -0.11178, 0.39784)>
# >
# Punto actual [[ 0.4265807 ]
#  [-0.11177722]
#  [ 0.3978417 ]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.12394405835938312 0.10995162232305922 0.002158286589012938
# [0.015988079831004143, -2.0558674971209925, -1.2395451704608362, -0.0932076613055628, -4.778697315846578, 20.925882530196596]
# [[ 0.23211314]
#  [ 0.41634065]
#  [-0.52774219]
#  [ 0.1078936 ]
#  [-0.2205553 ]
#  [ 0.05630168]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18924228,  0.164008  ,  0.96813673],
#        [ 0.47690976,  0.87720575, -0.05538191],
#        [-0.85833818,  0.45123326, -0.24422143]])>
# <Vector: (0.42551, -0.11067, 0.39817)>
# >
# Punto actual [[ 0.42550584]
#  [-0.11067161]
#  [ 0.39816744]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.12293471501544113 0.10889896474476139 0.0018325494502715112
# [0.019257526844739914, -2.0495055357562464, -1.2477195898639124, -0.09153157869447881, -4.78181761900057, 20.926747274382997]
# [[ 0.23165203]
#  [ 0.4126976 ]
#  [-0.52240706]
#  [ 0.10602329]
#  [-0.22012795]
#  [ 0.05623173]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18924337,  0.16391137,  0.96815288],
#        [ 0.47686751,  0.87723352, -0.05530587],
#        [-0.85836142,  0.45121438, -0.24417464]])>
# <Vector: (0.42449, -0.10964, 0.39845)>
# >
# Punto actual [[ 0.42448572]
#  [-0.10963561]
#  [ 0.39844995]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.12197578008634967 0.1079116664366936 0.0015500456498406326
# [0.022335225716233253, -2.043562714253561, -1.2554753462420862, -0.08973533311952764, -4.784722749386923, 20.92743153570502]
# [[ 0.2312072 ]
#  [ 0.40925786]
#  [-0.51734373]
#  [ 0.10423826]
#  [-0.21972115]
#  [ 0.05613854]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18924839,  0.16382766,  0.96816607],
#        [ 0.47686112,  0.8772418 , -0.05522944],
#        [-0.85836386,  0.45122868, -0.24413964]])>
# <Vector: (0.42330, -0.10848, 0.39880)>
# >
# Punto actual [[ 0.42329708]
#  [-0.108481  ]
#  [ 0.39879804]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.12085723533473942 0.10681029261523446 0.0012019626171896917
# [0.025796419009566307, -2.036708656941549, -1.2642605940448206, -0.08784372011293584, -4.787998501454489, 20.928247880919862]
# [[ 0.2307226 ]
#  [ 0.4052747 ]
#  [-0.51155774]
#  [ 0.10225227]
#  [-0.21927701]
#  [ 0.0560428 ]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18914719,  0.16371513,  0.96820488],
#        [ 0.47691759,  0.8772155 , -0.05515963],
#        [-0.85835479,  0.45132065, -0.24400147]])>
# <Vector: (0.42221, -0.10738, 0.39913)>
# >
# Punto actual [[ 0.42221063]
#  [-0.10738167]
#  [ 0.39913249]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.11983372283822363 0.10576063976729308 0.0008675080563873779
# [0.029113803058862686, -2.0304301420794886, -1.2722438017474573, -0.08607131639589483, -4.7911428848849695, 20.92910022734015]
# [[ 0.23019688]
#  [ 0.40155135]
#  [-0.50623129]
#  [ 0.10047758]
#  [-0.21879785]
#  [ 0.05591323]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18918151,  0.16362094,  0.9682141 ],
#        [ 0.47692687,  0.877217  , -0.0550553 ],
#        [-0.85834207,  0.45135188, -0.24398846]])>
# <Vector: (0.42098, -0.10615, 0.39947)>
# >
# Punto actual [[ 0.42098084]
#  [-0.10615138]
#  [ 0.39946569]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.11867388711371182 0.10458477884087292 0.0005343135759164238
# [0.03285025805234909, -2.0233472029315394, -1.2813399473773401, -0.08413154283632451, -4.794657651578085, 20.930000972731996]
# [[ 0.22959258]
#  [ 0.39738457]
#  [-0.50015852]
#  [ 0.09837966]
#  [-0.2182377 ]
#  [ 0.05579791]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18910819,  0.16361494,  0.96822944],
#        [ 0.47693055,  0.87721322, -0.05508376],
#        [-0.85835619,  0.45136141, -0.24392117]])>
# <Vector: (0.41980, -0.10505, 0.39978)>
# >
# Punto actual [[ 0.41980338]
#  [-0.10505305]
#  [ 0.39978336]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.11756214349554728 0.1035340255061226 0.0002166361246221878
# [0.03625115752220154, -2.0166967550860804, -1.289837662373678, -0.08229953447450811, -4.7979809681521814, 20.93081707952826]
# [[ 0.2290944 ]
#  [ 0.39345957]
#  [-0.49447936]
#  [ 0.09644471]
#  [-0.21778032]
#  [ 0.05569521]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18911203,  0.16353615,  0.968242  ],
#        [ 0.47690315,  0.87723222, -0.05501833],
#        [-0.85837056,  0.45135303, -0.24388608]])>
# <Vector: (0.41850, -0.10381, 0.40009)>
# >
# Punto actual [[ 0.41850131]
#  [-0.10380904]
#  [ 0.4000947 ]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.116331306343805 0.10234274198313469 -9.469624664001617e-05
# [0.04010745510458946, -2.0093496481524866, -1.2993410269366663, -0.08020383516420537, -4.8016515413867396, 20.931705665572572]
# [[ 0.2284704 ]
#  [ 0.38910923]
#  [-0.48810315]
#  [ 0.09422258]
#  [-0.21720189]
#  [ 0.05557393]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18903297,  0.16332664,  0.9682928 ],
#        [ 0.47692591,  0.87722978, -0.05485972],
#        [-0.85837533,  0.45143363, -0.24372005]])>
# <Vector: (0.41715, -0.10252, 0.40046)>
# >
# Punto actual [[ 0.41714979]
#  [-0.10252325]
#  [ 0.40046358]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.11505214728693057 0.10111017597335176 -0.00046357814948428934
# [0.044107191264629364, -2.00177508989443, -1.3089163939105433, -0.078132454548971, -4.80536932149996, 20.93267793653815]
# [[ 0.2277784 ]
#  [ 0.38453554]
#  [-0.48158503]
#  [ 0.09208289]
#  [-0.21656535]
#  [ 0.05540828]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.1889584 ,  0.16322685,  0.96832418],
#        [ 0.4770213 ,  0.87718304, -0.05477778],
#        [-0.85833875,  0.45156053, -0.24361379]])>
# <Vector: (0.41586, -0.10134, 0.40079)>
# >
# Punto actual [[ 0.41586051]
#  [-0.10133982]
#  [ 0.40078687]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.11383040126230769 0.09997460453242474 -0.0007868674774581814
# [0.04784364998340607, -1.994620148335592, -1.318000618611471, -0.07619268098940069, -4.808908406888143, 20.933674049361635]
# [[ 0.22714909]
#  [ 0.38022753]
#  [-0.47539984]
#  [ 0.09002026]
#  [-0.21598379]
#  [ 0.05527078]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18916199,  0.16322943,  0.968284  ],
#        [ 0.476964  ,  0.87721909, -0.05469936],
#        [-0.85832575,  0.45148957, -0.24379107]])>
# <Vector: (0.41446, -0.10004, 0.40102)>
# >
# Punto actual [[ 0.414458  ]
#  [-0.10003534]
#  [ 0.40102485]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.11249974342820933 0.09872161858588227 -0.0010248437833625017
# [0.05199955403804779, -1.9868171850787562, -1.3282459417926233, -0.07404882112611944, -4.812853876744406, 20.934610795958925]
# [[ 0.22641895]
#  [ 0.37561958]
#  [-0.46846441]
#  [ 0.08748522]
#  [-0.21529075]
#  [ 0.05517861]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18897022,  0.16303723,  0.96835382],
#        [ 0.47699442,  0.87720823, -0.054608  ],
#        [-0.85835108,  0.45158009, -0.24353408]])>
# <Vector: (0.41309, -0.09882, 0.40139)>
# >
# Punto actual [[ 0.41308738]
#  [-0.09881577]
#  [ 0.40138657]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.11119770623464349 0.0975490323993012 -0.0013865624363228214
# [0.05592738464474678, -1.9793379942523401, -1.3375819365130823, -0.07203704515566045, -4.816571537648336, 20.935571384414125]
# [[ 0.2257225 ]
#  [ 0.37102014]
#  [-0.4620168 ]
#  [ 0.08544839]
#  [-0.21465262]
#  [ 0.05499538]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18894834,  0.16293146,  0.96837589],
#        [ 0.47699915,  0.87721106, -0.05452126],
#        [-0.85835327,  0.45161277, -0.24346574]])>
# <Vector: (0.41157, -0.09746, 0.40170)>
# >
# Punto actual [[ 0.41157471]
#  [-0.09746113]
#  [ 0.40170469]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1097588937527415 0.09624527071718336 -0.0017046824525958036
# [0.06033458188176155, -1.9710786978351038, -1.348102871571676, -0.06983405748476201, -4.820755902920858, 20.936627578719545]
# [[ 0.22490993]
#  [ 0.36599683]
#  [-0.45476536]
#  [ 0.08300778]
#  [-0.21389366]
#  [ 0.05483345]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18894955,  0.16282048,  0.96839432],
#        [ 0.47697444,  0.87723034, -0.05442716],
#        [-0.85836673,  0.45161536, -0.24341348]])>
# <Vector: (0.41014, -0.09620, 0.40196)>
# >
# Punto actual [[ 0.41014432]
#  [-0.09620059]
#  [ 0.40195693]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1083965764121869 0.0950308487182952 -0.00195691880699546
# [0.06447775661945343, -1.9633472601519983, -1.3580969015704554, -0.06764251390566045, -4.824677411709921, 20.937588167174745]
# [[ 0.22413249]
#  [ 0.36129159]
#  [-0.44788294]
#  [ 0.08063507]
#  [-0.21316584]
#  [ 0.05468169]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18888602,  0.16271194,  0.96842496],
#        [ 0.47698698,  0.87722796, -0.05435557],
#        [-0.85837375,  0.45165909, -0.24330757]])>
# <Vector: (0.40856, -0.09483, 0.40227)>
# >
# Punto actual [[ 0.40855985]
#  [-0.09482688]
#  [ 0.40226592]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1068855429805924 0.09370607000772138 -0.0022659019323265027
# [0.06905273348093033, -1.9548242727862757, -1.3689168135272425, -0.06537944475282842, -4.829040710126058, 20.938692522033143]
# [[ 0.22325383]
#  [ 0.35605324]
#  [-0.44036312]
#  [ 0.0781378 ]
#  [-0.21234458]
#  [ 0.05450057]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18873949,  0.16265682,  0.96846278],
#        [ 0.47713482,  0.87714892, -0.0543336 ],
#        [-0.85832381,  0.45183242, -0.24316188]])>
# <Vector: (0.40705, -0.09358, 0.40253)>
# >
# Punto actual [[ 0.40705062]
#  [-0.09357505]
#  [ 0.40252814]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1054443603610471 0.09249764624058396 -0.0025281189254291606
# [0.07329177856445312, -1.9468291441546839, -1.379150692616598, -0.06312829652895147, -4.83312958875765, 20.93986911772101]
# [[ 0.22245972]
#  [ 0.35112592]
#  [-0.4332596 ]
#  [ 0.0757628 ]
#  [-0.21160474]
#  [ 0.054329  ]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18881954,  0.16253278,  0.96846801],
#        [ 0.4769932 ,  0.87723277, -0.05422321],
#        [-0.85838492,  0.45171425, -0.24316571]])>
# <Vector: (0.40538, -0.09216, 0.40279)>
# >
# Punto actual [[ 0.40537668]
#  [-0.09215604]
#  [ 0.4027875 ]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.10384373706013111 0.09112648799778979 -0.0027874760956670204
# [0.07811804860830307, -1.9379213492022913, -1.390545670186178, -0.06080514589418584, -4.837696019803182, 20.940865468963075]
# [[ 0.22147948]
#  [ 0.34564526]
#  [-0.42530003]
#  [ 0.07306236]
#  [-0.21067911]
#  [ 0.05415345]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18848715,  0.16235034,  0.96856335],
#        [ 0.47712277,  0.87716499, -0.05417975],
#        [-0.85838596,  0.45191144, -0.24279537]])>
# <Vector: (0.40375, -0.09086, 0.40313)>
# >
# Punto actual [[ 0.40374613]
#  [-0.09085936]
#  [ 0.4031258 ]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.10228247013011528 0.08987228839150783 -0.003125762068440678
# [0.08262037485837936, -1.9294222036944788, -1.4010909239398401, -0.05853015581239873, -4.842023793851034, 20.94206614492743]
# [[ 0.22059348]
#  [ 0.34027574]
#  [-0.41786552]
#  [ 0.0707955 ]
#  [-0.20986259]
#  [ 0.05391642]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18849794,  0.16217914,  0.96858993],
#        [ 0.47714411,  0.87716363, -0.05401353],
#        [-0.85837173,  0.45197554, -0.24272636]])>
# <Vector: (0.40200, -0.08941, 0.40336)>
# >
# Punto actual [[ 0.40199565]
#  [-0.08941308]
#  [ 0.40336201]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.1006040463531373 0.08847200687220316 -0.003361958542475731
# [0.0876503735780716, -1.9202502409564417, -1.4128335157977503, -0.05606300035585576, -4.846734348927633, 20.943290662749696]
# [[ 0.21950987]
#  [ 0.33456185]
#  [-0.40960824]
#  [ 0.06803328]
#  [-0.20884072]
#  [ 0.05370488]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18861169,  0.16207422,  0.96858535],
#        [ 0.47713719,  0.87717645, -0.05386623],
#        [-0.85835059,  0.4519883 , -0.24277737]])>
# <Vector: (0.40033, -0.08806, 0.40354)>
# >
# Punto actual [[ 0.4003348 ]
#  [-0.08806123]
#  [ 0.40354328]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.0990093740089313 0.08716185785780388 -0.003543218683313682
# [0.09241635352373123, -1.9115827719317835, -1.4239886442767542, -0.05379993120302373, -4.851205174122946, 20.944431495650697]
# [[ 0.21846195]
#  [ 0.32918205]
#  [-0.40175354]
#  [ 0.06535102]
#  [-0.20784501]
#  [ 0.05352648]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18837912,  0.16191275,  0.96865761],
#        [ 0.47717221,  0.87716018, -0.05382102],
#        [-0.8583822 ,  0.45207773, -0.24249893]])>
# <Vector: (0.39848, -0.08660, 0.40381)>
# >
# Punto actual [[ 0.3984848 ]
#  [-0.08659817]
#  [ 0.40381005]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.09723062301637 0.0857425391915038 -0.0038099739569103204
# [0.09768529236316681, -1.902050797139303, -1.4360058943377894, -0.05122501054872686, -4.856274191533224, 20.945716094954896]
# [[ 0.21729823]
#  [ 0.32312969]
#  [-0.39322817]
#  [ 0.06265236]
#  [-0.20675654]
#  [ 0.05325834]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18848914,  0.16187084,  0.96864321],
#        [ 0.47718628,  0.87715831, -0.05372662],
#        [-0.85835022,  0.45209637, -0.24257736]])>
# <Vector: (0.39675, -0.08524, 0.40396)>
# >
# Punto actual [[ 0.39675432]
#  [-0.08524216]
#  [ 0.40396154]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.09556446112767376 0.08442579996317154 -0.003961455888957673
# [0.10261942446231842, -1.8931310812579554, -1.4474614302264612, -0.048961941395894826, -4.860960427914755, 20.946928691848207]
# [[ 0.21617556]
#  [ 0.31756177]
#  [-0.38511874]
#  [ 0.05989865]
#  [-0.20568642]
#  [ 0.05307407]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18844647,  0.16169117,  0.96868152],
#        [ 0.47714024,  0.87719127, -0.05359727],
#        [-0.85838518,  0.45209672, -0.24245296]])>
# <Vector: (0.39482, -0.08374, 0.40416)>
# >
# Punto actual [[ 0.39481637]
#  [-0.08373811]
#  [ 0.40416197]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.09369593119481642 0.08296389216588171 -0.004161873389008039
# [0.10816362500190735, -1.8832271734820765, -1.4600299040423792, -0.04638797441591436, -4.866208736096517, 20.948200893386293]
# [[ 0.21486654]
#  [ 0.31127569]
#  [-0.37616524]
#  [ 0.05700353]
#  [-0.20444907]
#  [ 0.05281055]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18845349,  0.16163991,  0.96868871],
#        [ 0.47724489,  0.87713918, -0.05351795],
#        [-0.85832546,  0.45221609, -0.24244176]])>
# <Vector: (0.39298, -0.08238, 0.40431)>
# >
# Punto actual [[ 0.39297671]
#  [-0.08237697]
#  [ 0.40430541]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.09191965509401763 0.08163963430463603 -0.004305306213489631
# [0.1132887527346611, -1.8739116827594202, -1.4719160238849085, -0.04401714006532842, -4.871097866688864, 20.94955773351996]
# [[ 0.21367282]
#  [ 0.30539368]
#  [-0.36770818]
#  [ 0.05421584]
#  [-0.20331438]
#  [ 0.05259572]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18829028,  0.16145254,  0.9687517 ],
#        [ 0.47724042,  0.87714713, -0.05342741],
#        [-0.85836376,  0.45226761, -0.24220996]])>
# <Vector: (0.39091, -0.08086, 0.40451)>
# >
# Punto actual [[ 0.39090943]
#  [-0.08086435]
#  [ 0.40451283]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# [[2. 0. 0.]
#  [0. 2. 0.]
#  [0. 0. 2.]] [[0.5 0.  0. ]
#  [0.  0.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.08992073291608307 0.08016661503634957 -0.004512703896284521
# [0.11907263845205307, -1.8635152021991175, -1.4849508444415491, -0.041382614766256154, -4.87662119070162, 20.950926256164003]
# [[ 0.21227737]
#  [ 0.29871752]
#  [-0.35836895]
#  [ 0.0513225 ]
#  [-0.20199836]
#  [ 0.05229641]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[-0.18829613,  0.1612543 ,  0.96878358],
#        [ 0.4771942 ,  0.87718257, -0.05325817],
#        [-0.85838818,  0.45226959, -0.2421197 ]])>
# <Vector: (0.38901, -0.07946, 0.40465)>
# >
# Punto actual [[ 0.38900547]
#  [-0.07945725]
#  [ 0.40464897]]
# punto deseado [[0.3]
#  [0. ]
#  [0.4]]
# ...
# velocidad -0.027943378914759807 0.08272941034851385 0.030229478414970347
# [-0.3835356871234339, -2.228330914174215, -1.3577259222613733, 0.454107403755188, -4.3868741432773035, 20.9167100906214]
# [[ 0.14381176]
#  [ 0.23348673]
#  [-0.25028274]
#  [ 0.01851327]
#  [-0.14039382]
#  [-0.00075722]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.0344883 ,  0.05020919,  0.99814307],
#        [ 0.46793902,  0.88168614, -0.06051955],
#        [-0.88308755,  0.46915731,  0.00691301]])>
# <Vector: (0.35554, -0.23857, 0.33951)>
# >
# Punto actual [[ 0.35553609]
#  [-0.23856952]
#  [ 0.33951282]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.02773953450132038 0.08668471961911094 0.030206757999996326
# [-0.38874704042543584, -2.231560532246725, -1.3517654577838343, 0.4514244794845581, -4.381838146840231, 20.916866254790712]
# [[ 0.15127666]
#  [ 0.23938907]
#  [-0.26021791]
#  [ 0.02255704]
#  [-0.14768953]
#  [-0.00081757]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03440869,  0.05050384,  0.99813096],
#        [ 0.46804729,  0.88161329, -0.06074329],
#        [-0.88303328,  0.46926258,  0.00669697]])>
# <Vector: (0.35507, -0.24043, 0.33956)>
# >
# Punto actual [[ 0.35506561]
#  [-0.24042918]
#  [ 0.3395577 ]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.027505012520089276 0.0908543159666303 0.030184400457793553
# [-0.39425784746278936, -2.234777275715963, -1.3457329908954065, 0.4484294652938843, -4.376550857220785, 20.916974019988466]
# [[ 0.15909453]
#  [ 0.24566167]
#  [-0.27074339]
#  [ 0.02683362]
#  [-0.1553292 ]
#  [-0.00084294]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03456842,  0.05053609,  0.9981238 ],
#        [ 0.46798909,  0.88163708, -0.0608463 ],
#        [-0.88305789,  0.46921441,  0.00682646]])>
# <Vector: (0.35462, -0.24206, 0.33971)>
# >
# Punto actual [[ 0.35462262]
#  [-0.24205689]
#  [ 0.33971305]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.027284179385273173 0.09450267984735075 0.030107010831830473
# [-0.39912254015077764, -2.237501923237936, -1.3401435057269495, 0.4457465410232544, -4.371790115033285, 20.91702289579718]
# [[ 0.16587189]
#  [ 0.25109667]
#  [-0.28005498]
#  [ 0.03071209]
#  [-0.16194927]
#  [-0.00092048]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03455607,  0.05075428,  0.99811316],
#        [ 0.46811121,  0.88155926, -0.06103415],
#        [-0.88299364,  0.46933706,  0.00670457]])>
# <Vector: (0.35413, -0.24380, 0.33979)>
# >
# Punto actual [[ 0.3541292 ]
#  [-0.24380053]
#  [ 0.33979439]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.027038198431100894 0.09840963240659137 0.030066484966891415
# [-0.4043219725238245, -2.2404068152057093, -1.334505860005514, 0.44293177127838135, -4.366778437291281, 20.917178583129335]
# [[ 0.17308012]
#  [ 0.25703553]
#  [-0.29008178]
#  [ 0.03481904]
#  [-0.16898952]
#  [-0.00095509]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03464969,  0.05080833,  0.99810717],
#        [ 0.46803595,  0.8815929 , -0.06112526],
#        [-0.88302987,  0.46926801,  0.0067668 ]])>
# <Vector: (0.35365, -0.24536, 0.33995)>
# >
# Punto actual [[ 0.35364699]
#  [-0.24535823]
#  [ 0.33995449]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.02679779026361269 0.10189883159707411 0.02998672379208832
# [-0.4090188185321253, -2.2428553740130823, -1.3293474356280726, 0.4403318166732788, -4.362172786389486, 20.917178583129335]
# [[ 0.17947267]
#  [ 0.26230329]
#  [-0.29910074]
#  [ 0.03857549]
#  [-0.17523096]
#  [-0.0010186 ]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03452381,  0.0508566 ,  0.99810907],
#        [ 0.46816585,  0.881525  , -0.06110979],
#        [-0.88296594,  0.46939032,  0.00662428]])>
# <Vector: (0.35317, -0.24697, 0.34006)>
# >
# Punto actual [[ 0.35317469]
#  [-0.24696954]
#  [ 0.34006441]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.02656231206951019 0.1055069524288515 0.0299319628475076
# [-0.413858715687887, -2.2455204168902796, -1.3239730040179651, 0.43751704692840576, -4.357316199933187, 20.91732282636969]
# [[ 0.18599679]
#  [ 0.2678657 ]
#  [-0.30854521]
#  [ 0.04247851]
#  [-0.181599  ]
#  [-0.00104115]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03463504,  0.05102425,  0.99809666],
#        [ 0.46818813,  0.88149925, -0.06131024],
#        [-0.88294976,  0.46942049,  0.00664182]])>
# <Vector: (0.35262, -0.24856, 0.34026)>
# >
# Punto actual [[ 0.35261991]
#  [-0.24855916]
#  [ 0.34026364]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.026285700887202182 0.10906530288641623 0.02983270392662437
# [-0.418675724660055, -2.247788731251852, -1.3189104239093226, 0.43478572368621826, -4.352698866521017, 20.91741867063849]
# [[ 0.19244091]
#  [ 0.27328636]
#  [-0.31784145]
#  [ 0.04636246]
#  [-0.18788841]
#  [-0.00109632]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03475271,  0.05117262,  0.99808497],
#        [ 0.46818865,  0.881486  , -0.06149654],
#        [-0.88294487,  0.46942923,  0.00667558]])>
# <Vector: (0.35213, -0.24998, 0.34045)>
# >
# Punto actual [[ 0.35212831]
#  [-0.24997986]
#  [ 0.34044834]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.02604057036781086 0.11224446820805614 0.02974068190729153
# [-0.4229648748980921, -2.2498539129840296, -1.3142903486834925, 0.4323066473007202, -4.3485954443561, 20.917490911467958]
# [[ 0.19814101]
#  [ 0.27817307]
#  [-0.32623485]
#  [ 0.04987566]
#  [-0.19344995]
#  [-0.00114943]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03484527,  0.05141789,  0.99806914],
#        [ 0.46820055,  0.88146149, -0.06175671],
#        [-0.88293491,  0.46944844,  0.00664088]])>
# <Vector: (0.35156, -0.25148, 0.34066)>
# >
# Punto actual [[ 0.35156406]
#  [-0.25147781]
#  [ 0.34065956]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.02575920541115199 0.11559542944813815 0.029635443118689188
# [-0.42751771608461553, -2.2518461386310022, -1.3096345106707972, 0.4296475648880005, -4.344301287327902, 20.917550754531312]
# [[ 0.20413422]
#  [ 0.28333829]
#  [-0.33509437]
#  [ 0.05358181]
#  [-0.19929696]
#  [-0.00118993]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03487402,  0.05138367,  0.9980699 ],
#        [ 0.46828239,  0.88141914, -0.0617406 ],
#        [-0.88289037,  0.4695317 ,  0.00667656]])>
# <Vector: (0.35105, -0.25276, 0.34089)>
# >
# Punto actual [[ 0.35104868]
#  [-0.25276309]
#  [ 0.34088794]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.02550219271956753 0.11846969252309433 0.029521650316155147
# [-0.4315074125873011, -2.2534902731524866, -1.3055413405047815, 0.42727577686309814, -4.3402937094317835, 20.917706680282045]
# [[ 0.2092338 ]
#  [ 0.2877656 ]
#  [-0.34274585]
#  [ 0.05681021]
#  [-0.20426996]
#  [-0.00123961]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03483548,  0.05142803,  0.99806896],
#        [ 0.46829207,  0.88141252, -0.06176175],
#        [-0.88288676,  0.46953927,  0.00662109]])>
# <Vector: (0.35051, -0.25411, 0.34112)>
# >
# Punto actual [[ 0.35050905]
#  [-0.25410721]
#  [ 0.34112479]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.025233070662986124 0.12147462095021358 0.029403639025889088
# [-0.4356649557696741, -2.2551830450641077, -1.3012798468219202, 0.4246879816055298, -4.336154643689291, 20.91774268148749]
# [[ 0.21452534]
#  [ 0.29243751]
#  [-0.35079938]
#  [ 0.06020437]
#  [-0.20942925]
#  [-0.00126915]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03493932,  0.05158494,  0.99805723],
#        [ 0.46830379,  0.88139314, -0.06194918],
#        [-0.88287644,  0.46955844,  0.00663786]])>
# <Vector: (0.34996, -0.25536, 0.34139)>
# >
# Punto actual [[ 0.34996433]
#  [-0.25535534]
#  [ 0.34138586]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.024961394760538356 0.12426407265570426 0.02927355256743968
# [-0.4395349661456507, -2.256575409566061, -1.2974618116961878, 0.4223165512084961, -4.332469884549276, 20.917814922316957]
# [[ 0.21943963]
#  [ 0.29675998]
#  [-0.35827901]
#  [ 0.06336668]
#  [-0.21422041]
#  [-0.00131348]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03508361,  0.05173432,  0.99804444],
#        [ 0.46826427,  0.8814001 , -0.06214857],
#        [-0.88289168,  0.46952895,  0.00669737]])>
# <Vector: (0.34939, -0.25664, 0.34166)>
# >
# Punto actual [[ 0.34939359]
#  [-0.25663588]
#  [ 0.34165896]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.024676731867632716 0.1271250545725798 0.029137468018794896
# [-0.44351274171938115, -2.2580040136920374, -1.2935360113727015, 0.4199209213256836, -4.328689638768331, 20.9178509235224]
# [[ 0.22444742]
#  [ 0.3012218 ]
#  [-0.36600193]
#  [ 0.06662933]
#  [-0.21910144]
#  [-0.00136978]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03523868,  0.05185768,  0.99803257],
#        [ 0.46838535,  0.88132285, -0.06233127],
#        [-0.88282127,  0.46966031,  0.00676727]])>
# <Vector: (0.34772, -0.25991, 0.34261)>
# >
# Punto actual [[ 0.34771619]
#  [-0.25991331]
#  [ 0.34261021]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.02384000565225004 0.13444318843273065 0.02866343574905545
# [-0.45400888124574834, -2.260740582142965, -1.2838175932513636, 0.4131171703338623, -4.318365995083944, 20.91815085409491]
# [[ 0.23720685]
#  [ 0.31258237]
#  [-0.38580737]
#  [ 0.075079  ]
#  [-0.23153347]
#  [-0.00149675]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03534478,  0.0522384 ,  0.99800897],
#        [ 0.46850725,  0.88123061, -0.06271823],
#        [-0.88275235,  0.46979119,  0.00667283]])>
# <Vector: (0.34602, -0.26287, 0.34367)>
# >
# Punto actual [[ 0.34601757]
#  [-0.2628667 ]
#  [ 0.34366742]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.022992556849464656 0.14103228983474858 0.02813653420427406
# [-0.4636300245868128, -2.2623494307147425, -1.2755230108844202, 0.406421422958374, -4.309118215237753, 20.918367338164735]
# [[ 0.24862545]
#  [ 0.32286325]
#  [-0.40375561]
#  [ 0.08276268]
#  [-0.24265545]
#  [-0.0015695 ]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03522578,  0.05237953,  0.99800578],
#        [ 0.4686401 ,  0.881155  , -0.06278791],
#        [-0.88268658,  0.46991728,  0.00649222]])>
# <Vector: (0.34548, -0.26370, 0.34397)>
# >
# Punto actual [[ 0.34547933]
#  [-0.26369877]
#  [ 0.34397092]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.022723999149330473 0.1428876733831015 0.02798526039669235
# [-0.4664219061480921, -2.2625768820392054, -1.2735002676593226, 0.4044567346572876, -4.306390349064962, 20.918463182433534]
# [[ 0.2518496 ]
#  [ 0.3257834 ]
#  [-0.40879268]
#  [ 0.08490063]
#  [-0.24579604]
#  [-0.00154489]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03544058,  0.05246477,  0.99799369],
#        [ 0.4686369 ,  0.88114413, -0.06296412],
#        [-0.88267968,  0.46992816,  0.00664133]])>
# <Vector: (0.34488, -0.26456, 0.34442)>
# >
# Punto actual [[ 0.34487741]
#  [-0.26456445]
#  [ 0.34442362]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.022423654718406745 0.14481754438710942 0.027759614727793574
# [-0.46935731569399053, -2.262625519429342, -1.2711780706988733, 0.40237295627593994, -4.303626839314596, 20.918571424468446]
# [[ 0.25521317]
#  [ 0.32873759]
#  [-0.41404881]
#  [ 0.08718492]
#  [-0.24907097]
#  [-0.00161884]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03536556,  0.05250205,  0.99799439],
#        [ 0.46872559,  0.88109707, -0.06296243],
#        [-0.8826356 ,  0.47001222,  0.00655144]])>
# <Vector: (0.34437, -0.26529, 0.34478)>
# >
# Punto actual [[ 0.3443672 ]
#  [-0.26528718]
#  [ 0.34477511]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.022169056458585128 0.14642835780163072 0.027584410190431653
# [-0.47184974351991826, -2.262625519429342, -1.2693589369403284, 0.40048062801361084, -4.301127020512716, 20.91865534780829]
# [[ 0.25800652]
#  [ 0.3312447 ]
#  [-0.41843897]
#  [ 0.08907746]
#  [-0.25179073]
#  [-0.00161689]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03531075,  0.05258218,  0.99799212],
#        [ 0.46878115,  0.88106427, -0.06300781],
#        [-0.88260828,  0.47006475,  0.00646151]])>
# <Vector: (0.34382, -0.26603, 0.34515)>
# >
# Punto actual [[ 0.34382348]
#  [-0.26602982]
#  [ 0.34515426]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.021897724785778942 0.14808319470746115 0.02739540511424338
# [-0.47442561784853154, -2.26254111925234, -1.2675517241107386, 0.3985159397125244, -4.298590485249655, 20.91870326994269]
# [[ 0.26088146]
#  [ 0.3338204 ]
#  [-0.42294846]
#  [ 0.09102063]
#  [-0.25458995]
#  [-0.00161522]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.03538974,  0.05263193,  0.9979867 ],
#        [ 0.46882092,  0.88103729, -0.06308916],
#        [-0.882584  ,  0.47010975,  0.00650473]])>
# <Vector: (0.34323, -0.26672, 0.34563)>
# >
# Punto actual [[ 0.34323398]
#  [-0.26672355]
#  [ 0.34562634]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.021603532926801918 0.14962869915193028 0.02716007146772771
# [-0.47692948976625615, -2.262097183858053, -1.2659724394427698, 0.39656364917755127, -4.2961618343936365, 20.918799352630067]
# [[ 0.26361602]
#  [ 0.33614741]
#  [-0.42711007]
#  [ 0.09284604]
#  [-0.25725264]
#  [-0.00165393]]
# Transformation from base to tcp is:  <Transform:
# <Orientation:
# array([[ 0.0353692 ,  0.05269485,  0.9979841 ],
#        [ 0.468865  ,  0.88101052, -0.06313537],
#        [-0.8825614 ,  0.47015287,  0.00645387]])>
# <Vector: (0.34272, -0.26730, 0.34603)>
# >
# Punto actual [[ 0.3427219 ]
#  [-0.26729789]
#  [ 0.34603247]]
# punto deseado [[ 0.3]
#  [-0.2]
#  [ 0.4]]
# [[1.  0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  1. ]] [[0.5 0.  0. ]
#  [0.  1.5 0. ]
#  [0.  0.  0.5]]
# velocidad -0.021347964705270804 0.15090799276739497 0.026957600606173783
# [-0.4790390173541468, -2.2616050879107874, -1.2647751013385218, 0.39483869075775146, -4.294092241917745, 20.918847274764467]
# [[ 0.26589021]
#  [ 0.33807527]
#  [-0.43053879]
#  [ 0.09434892]
#  [-0.25946744]
#  [-0.00165959]]
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "D:\PROGRAMAS\anaconda\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "D:\PROGRAMAS\anaconda\lib\site-packages\urx\ursecmon.py", line 286, in run
#     data = self._get_data()
#   File "D:\PROGRAMAS\anaconda\lib\site-packages\urx\ursecmon.py", line 333, in _get_data
#     tmp = self._s_secondary.recv(1024)
# socket.timeout: timed out

# %%
import numpy as np

e = np.zeros((3,1));
P = np.array([2,2,0]).reshape(3,1);
Po = np.array([3,3,3]).reshape(3,1);
e = Po - P      
k2 = np.diag([1,2,3]);
k1 = np.diag([1,2,1]);
hv = np.matmul(k2,np.tanh(np.matmul(k1,e)))
print(hv)
print(k2)

# %%
a =(np.matmul(k1,np.tanh(np.matmul(k2,e))))

# %%
print(a[1,0])

# %%
import json
import numpy as np
with open('data2.json', 'r') as fa:
    data = json.load(fa)
k2 = ( np.diag([1.1,2.1,3.3]));
k1 = ( np.diag([1.2,2.1,1.3]));

# %%
print(k2[0,0])
# Out:
# 0.5

# %%
k1[0,0] = data['controller']['k11']
k1[1,1] = data['controller']['k12']
k1[2,2] = data['controller']['k13']
k2[0,0] = data['controller']['k21']
k2[1,1] = data['controller']['k22']
k2[2,2] = data['controller']['k23']
x_refr = data['poss']['xref']
y_refr = data['poss']['yref']
z_refr = data['poss']['zref']
\

# %%
hv = np.matmul(k2,np.tanh(np.matmul(k1,e)))

# %%
k2[0,0] = float(data['controller']['k21'])
